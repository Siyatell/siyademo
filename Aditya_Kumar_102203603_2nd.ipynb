# %% [markdown]
# <a href="https://colab.research.google.com/github/Siyatell/siyademo/blob/main/Aditya_Kumar_102203603_2nd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.DataFrame()

# %%
df['Name']=['aditya','aditya','simar','alok','jyotish','gurjot','anil','ananya','siya','subhash']
df['Age']=[21,21,22,21,30,25,23,26,32,31]
df['Gender']=['male','male','male','male','male','male','male','female','female','male']
df['city']=['chandigarh','chandigarh','gujrat','zirakpur','chandigarh','kerala','jammu','bhopal','lucknow','telangana']
df
# Out:
#       Name  Age  Gender        city
# 0   aditya   21    male  chandigarh
# 1   aditya   21    male  chandigarh
# 2    simar   22    male      gujrat
# 3     alok   21    male    zirakpur
# 4  jyotish   30    male  chandigarh
# 5   gurjot   25    male      kerala
# 6     anil   23    male       jammu
# 7   ananya   26  female      bhopal
# 8     siya   32  female     lucknow
# 9  subhash   31    male   telangana

# %%
df.iloc[4]
# Out:
# Name         jyotish
# Age               30
# Gender          male
# city      chandigarh
# Name: 4, dtype: object

# %%
df.iloc[1:4]
# Out:
#      Name  Age Gender        city
# 1  aditya   21   male  chandigarh
# 2   simar   22   male      gujrat
# 3    alok   21   male    zirakpur

# %%
df[df['Gender']=='female']
df.replace('female','Woman')
# Out:
#       Name  Age Gender        city
# 0   aditya   21   male  chandigarh
# 1   aditya   21   male  chandigarh
# 2    simar   22   male      gujrat
# 3     alok   21   male    zirakpur
# 4  jyotish   30   male  chandigarh
# 5   gurjot   25   male      kerala
# 6     anil   23   male       jammu
# 7   ananya   26  Woman      bhopal
# 8     siya   32  Woman     lucknow
# 9  subhash   31   male   telangana

# %%
df.rename(columns={'Gender':'Sex'})
# Out:
#       Name  Age     Sex        city
# 0   aditya   21    male  chandigarh
# 1   aditya   21    male  chandigarh
# 2    simar   22    male      gujrat
# 3     alok   21    male    zirakpur
# 4  jyotish   30    male  chandigarh
# 5   gurjot   25    male      kerala
# 6     anil   23    male       jammu
# 7   ananya   26  female      bhopal
# 8     siya   32  female     lucknow
# 9  subhash   31    male   telangana

# %%
df['Age'].max()
# Out:
# 32

# %%
df['Age'].sum()
# Out:
# 252

# %%
df['Gender'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df.drop(['Age'],axis=1)
# Out:
#       Name  Gender        city
# 0   aditya    male  chandigarh
# 1   aditya    male  chandigarh
# 2    simar    male      gujrat
# 3     alok    male    zirakpur
# 4  jyotish    male  chandigarh
# 5   gurjot    male      kerala
# 6     anil    male       jammu
# 7   ananya  female      bhopal
# 8     siya  female     lucknow
# 9  subhash    male   telangana

# %%
df.drop_duplicates()
# Out:
#       Name  Age  Gender        city
# 0   aditya   21    male  chandigarh
# 2    simar   22    male      gujrat
# 3     alok   21    male    zirakpur
# 4  jyotish   30    male  chandigarh
# 5   gurjot   25    male      kerala
# 6     anil   23    male       jammu
# 7   ananya   26  female      bhopal
# 8     siya   32  female     lucknow
# 9  subhash   31    male   telangana
